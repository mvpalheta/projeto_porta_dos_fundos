# %% [markdown]
# <div align="center"><b><h1> Buscando dados de vídeos do YouTube - Parte 2 </h1></b></div>
#
# <img src="youtube.com_.jpg" width="480">
#
# ### Objetivo
# Apresentar um exemplo de como baixar dados de vídeos de um canal a partir da API do YouTube. Neste caso, foi utilizado o canal de humor "Porta dos Fundos"
#
# Para importar nossa base de dados vamos utilizar a seguinte estratégia:<br>
# 1 - utilizar a biblioteca "yt_videos_list" para retornar a lista de vídeos publicados no canal desejado. Essa biblioteca facilita bastante este processo;<br>
# 2 - em seguida, será realizada a conexão com a API do YouTube e um loop através dos vídeos para obter informações como título, visualizações, elenco, diretor(a), roteiristas, likes, dislikes e data de publicação as quais serão armazenadas em um dicionário;<br>
# 3 - após isto, os dados serão carregados em um pandas dataframe e se procederá às devidas limpezas para se obter a base de dados final, pronta para análise.
# <br>
# <br>
# Vamos lá!!!

# %% [markdown]
# ### Importando as libraries necessárias

# %%
from yt_videos_list import ListCreator
import pandas as pd
import re
import time
from googleapiclient.discovery import build
from IPython.core.interactiveshell import InteractiveShell
from IPython.core.display import HTML
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Instanciando o driver do navegador e o listcreator
# As opções para o driver são as seguintes:<br>
# Firefox (default) (driver='firefox') <br>
# Opera(driver='opera') <br>
# Safari (MacOS only) (driver='safari') <br>
# Chrome (driver='chrome') <br>
# Brave (driver='brave') <br>
# Edge (Windows only) (driver='edge') <br>

# %%
my_driver = 'chrome' # substitua pelo driver (nome) do seu navegador, conforme acima
lc = ListCreator(csv=True,
                 md=False,
                 txt=False,
                 #headless=True,
                 driver=my_driver,
                 scroll_pause_time=2,
                 reverse_chronological=True)

# %% [markdown]
# ### Criando a lista de vídeos do canal

# %%
filename = 'PortadosFundosvideo'
lc.create_list_for(url='https://www.youtube.com/c/PortadosFundos/videos', log_silently=True, file_name=filename)
# Out:
# 'PortadosFundosvideo'

# %% [markdown]
# ### Carregando a lista de vídeos em um dataframe e observando os primeiros registros

# %%
df = pd.read_csv(filename+'.csv')
df.head()
# Out:
#    Video Number                  Video Title  \
# 0          1651                  TÁ TUDO BEM
# 1          1650                        KATIA
# 2          1649  RIR É UM ATO DE RESISTÊNCIA
# 3          1648              SONHEI COM VOCÊ
# 4          1647                  DIVERSIDADE
#
#                                      Video URL  Watched?  Watch again later?  \
# 0  https://www.youtube.com/watch?v=xsLrkt3XEaM       NaN                 NaN
# 1  https://www.youtube.com/watch?v=onNxHMHBdoA       NaN                 NaN
# 2  https://www.youtube.com/watch?v=5wAZaD2Z4IY       NaN                 NaN
# 3  https://www.youtube.com/watch?v=LVwbiEtAJ6Q       NaN                 NaN
# 4  https://www.youtube.com/watch?v=o84iIil6DU0       NaN                 NaN
#
#    Notes
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
# ### Excluindo os vídeos de making of para reduzir dupla contagem de atores/diretores/roteiristas na mesma peça

# %%
df = df[~df['Video Title'].str.contains('MAKING OF')]
df.shape
# Out:
# (1410, 6)

# %% [markdown]
# ### Gerando uma lista de ID's dos vídeos, para consulta das informações via API

# %%
df['video_id'] = df['Video URL'].str.extract(r'v=(.*)', expand = True)
video_id_list = df['video_id'].tolist()

# %% [markdown]
# ### Verificando quantidade de vídeos e observando os 10 primeiros registros

# %%
len(video_id_list)
video_id_list[:10]
# Out:
# 1410
# ['xsLrkt3XEaM',
#  'onNxHMHBdoA',
#  '5wAZaD2Z4IY',
#  'LVwbiEtAJ6Q',
#  'o84iIil6DU0',
#  'J7M-9MJThu4',
#  'dmlh-1ettn0',
#  '2toRdsfyG2w',
#  'RhcN-5RmVBM',
#  'rd5YldXpG-g']

# %% [markdown]
# ### Conectando à API do Google para retornar as informações desejadas
# Caso não saiba como gerar uma API Key para o YouTube, é só dar uma conferida no vídeo do link abaixo: <br>
#
# https://youtu.be/3jZ5vnv-LZc

# %%
youTubeApiKey= # Aqui você deve inserir sua API Key, gerada via Google Cloud Plataform
youtube=build('youtube','v3', developerKey=youTubeApiKey)

# %% [markdown]
# ### Buscando os dados desejados na API do YouTube, para os vídeos na lista

# %%
# %%time

# incializando o dicionário que irá guardar as informações extraídas dos vídeos
result = {"title":[], "views":[], "cast":[], "script":[], "directing":[], "date_published":[], "likes":[], "dislikes":[]}

n = 0

for video_id in video_id_list:
    print(n)
    print(video_id)    
    stat = youtube.videos().list(id=video_id, part='statistics').execute()
    snip = youtube.videos().list(id=video_id, part='snippet').execute()
    description=str(snip['items'][0]['snippet']['localized'])
    
    for character in ['Elenco', 'Elenco:', 'elenco', 'ELENCO:', "ELENCO "]:
        description = description.replace(character, "ELENCO")

    for character in ['Roteiro', 'Roteiro:', 'roteiro', 'ROTEIRO:', "ROTEIRO "]:
        description = description.replace(character, "ROTEIRO")

    for character in ['Direção', 'Direção:', 'direção', 'DIREÇÃO:', "DIREÇÃO "]:
        description = description.replace(character, "DIREÇÃO")

    for character in [' \\n ', ' \\n', '\\n ']:
        description = description.replace(character, "\\n")
    
    #title
    result["title"].append(snip['items'][0]['snippet']['title'])
    #views
    try:
        result["views"].append(stat['items'][0]['statistics']['viewCount'])
    except:
        result["views"].append('')
    #cast
    try:
        result["cast"].append(''.join(re.findall(r'\\nELENCO\\n(.*?)\\n\\n', description)))
    except:
        result["cast"].append('')
    #script
    try:        
        result["script"].append(''.join(re.findall(r'\\nROTEIRO\\n(.*?)\\n\\n', description)))
    except:
        result["script"].append('')
    #directing
    try:
        result["directing"].append(''.join(re.findall(r'\\nDIREÇÃO\\n(.*?)\\n\\n', description)))    
    except:
        result["directing"].append('')
    # date published
    result["date_published"].append(snip['items'][0]['snippet']['publishedAt'])
    #likes
    try:
        result["likes"].append(stat['items'][0]['statistics']['likeCount'])
    except:
        result["likes"].append('')
    #dislikes
    try:
        result["dislikes"].append(stat['items'][0]['statistics']['dislikeCount'])
    except:
        result["dislikes"].append('')
    n = n + 1
    time.sleep(1)

# %% [markdown]
# ### Carregando os dados em um dataframe para realizar as limpezas necessárias

# %%
df = pd.DataFrame.from_dict(result)
df.shape
df.head(10)
df.info()
# Out:
# (1410, 8)
#                          title   views  \
# 0                  TÁ TUDO BEM  334867
# 1                        KATIA  384456
# 2  RIR É UM ATO DE RESISTÊNCIA  412737
# 3              SONHEI COM VOCÊ  423480
# 4                  DIVERSIDADE  477663
# 5                VIDA EM MARTE  543461
# 6               LEILÃO ONLINE  869218
# 7                  AMIGA, PARE  467961
# 8                 ERIC QUERIDO  426112
# 9                CÂMERA LIGADA  633554
#
#                                                 cast  \
# 0                      Fábio de Luca\nRafael Infante
# 1                       Evelyn Castro\nFábio de Luca
# 2
# 3                      Estevam Nabote\nNathalia Cruz
# 4                   Gregório Duviver\nRafael Infante
# 5            João Vicente de Castro\nPedro Benevides
# 6                                      Fábio Porchat
# 7                         Thati Lopes\nEvelyn Castro
# 8  Gregório Duvivier\nEvelyn Castro\nPedro Benevi...
# 9  Rafael Infante\nNoemia Oliveira\nEstevam Nabot...
#
#                           script            directing        date_published  \
# 0                Gabriel Esteves     Zaga Martelletto  2021-05-10T14:00:32Z
# 1                    Matheus MAD      Bianca Frossard  2021-05-08T14:00:11Z
# 2                                                      2021-05-06T14:00:04Z
# 3                    Matheus MAD      Bianca Frossard  2021-05-03T14:00:07Z
# 4                 Gustavo Vilela  Rodrigo Van Der Put  2021-05-01T14:00:31Z
# 5                    Matheus MAD          Gigi Soares  2021-04-29T14:00:07Z
# 6  Jhonathan Marques\nEdu Araujo      Bianca Frossard  2021-04-26T14:00:14Z
# 7                  Nathalia Cruz  Rodrigo Van Der Put  2021-04-24T14:00:01Z
# 8              Gregório Duvivier  Rodrigo Van Der Put  2021-04-22T14:00:09Z
# 9               Jhonatan Marques      Bianca Frossard  2021-04-19T14:00:14Z
#
#    likes dislikes
# 0  44800      651
# 1  37581      511
# 2  92594      688
# 3  46417      338
# 4  53420      799
# 5  51774     1008
# 6  72699      843
# 7  42214     1171
# 8  42127     1379
# 9  53421      522
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1410 entries, 0 to 1409
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           1410 non-null   object
#  1   views           1410 non-null   object
#  2   cast            1410 non-null   object
#  3   script          1410 non-null   object
#  4   directing       1410 non-null   object
#  5   date_published  1410 non-null   object
#  6   likes           1410 non-null   object
#  7   dislikes        1410 non-null   object
# dtypes: object(8)
# memory usage: 88.2+ KB

# %% [markdown]
# ### Convertendo as variáveis 'views', 'likes' e 'dislikes' de string para numérico

# %%
df['views'] = df.views.astype(float)
df['likes'] = df.likes.replace('', np.nan).astype(float)
df['dislikes'] = df.dislikes.replace('', np.nan).astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1410 entries, 0 to 1409
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           1410 non-null   object
#  1   views           1410 non-null   float64
#  2   cast            1410 non-null   object
#  3   script          1410 non-null   object
#  4   directing       1410 non-null   object
#  5   date_published  1410 non-null   object
#  6   likes           1402 non-null   float64
#  7   dislikes        1402 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 88.2+ KB

# %% [markdown]
# ### Substituindo o '\\\n' por vírgula para facilitar dividir atores, roteiristas e diretores em linhas

# %%
df['cast'] = df['cast'].replace(r'\\n',',', regex=True)
df['cast'] = df['cast'].replace('-',',', regex=True)
df['script'] = df['script'].replace(r'\\n',',', regex=True)
df['directing'] = df['directing'].replace(r'\\n',',', regex=True)

# %%
df.tail(50)
# Out:
#                                                   title       views  \
# 1360                                            TAXISTA   7479297.0
# 1361                      CLARICE FALCÃO - OITAVO ANDAR  16431313.0
# 1362                                     COM QUEM SERÁ?  13043259.0
# 1363                                                 DR   3636586.0
# 1364                                            TROCADO   6322735.0
# 1365                                 BARATA NO BANHEIRO  10486388.0
# 1366                        TEQUILA - "Quem tá dentro?"   3664137.0
# 1367                                  TROCA DE PRESENTE   3416367.0
# 1368                                                VAN   7338839.0
# 1369                                            TIPO...   5934151.0
# 1370               MESA REDONDA - Porta Dos Fundos Nº 4   2205392.0
# 1371             TRAGO A PESSOA - Porta dos Fundos Nº 4   6465080.0
# 1372                                     TESTE PRA SACI   5683804.0
# 1373                               PORTA DOS FUNDOS N°4   2962141.0
# 1374                                       NOME DO BEBÊ  10417290.0
# 1375                                      CICLO DA VIDA   9298917.0
# 1376                                  TÉRMINO DE NAMORO  20015925.0
# 1377                              PREPARADORA DE ELENCO   4512376.0
# 1378                                     PONTO DE VISTA   7989988.0
# 1379                                         BRAINSTORM   7096828.0
# 1380                                      LINHA DA VIDA   3779985.0
# 1381                                               COMA  11102650.0
# 1382                                           SEX SHOP   7056132.0
# 1383                                SETOR DE RH - JESUS   9529509.0
# 1384           ASSEMBLEIA GERAL - Porta dos Fundos Nº 3   3724914.0
# 1385                  PODE SER? - Porta dos Fundos Nº 3   4151830.0
# 1386                                       CANCELAMENTO   6946014.0
# 1387                              PORTA DOS FUNDOS Nº 3   3329127.0
# 1388                                       MEU PRÍNCIPE   7437905.0
# 1389                                  PROGRAMA POLÍTICO  10406304.0
# 1390                                           ENCONTRO   8606314.0
# 1391                                        FILME PORNÔ  24695393.0
# 1392                          SETOR DE RH - SUPERGÊMEOS   6177923.0
# 1393                                       SOBRE A MESA  26771536.0
# 1394           MINUTO DA MARMOTA - Porta dos Fundos N°2   3879821.0
# 1395                GALÃ GLOBAL - Porta dos Fundos N° 2   3875697.0
# 1396  COMERCIAL DE PASTA DE DENTE - Porta dos fundos...   3181980.0
# 1397                                     MÉDICO VIDENTE  11485609.0
# 1398                               PORTA DOS FUNDOS N°2   3850173.0
# 1399                                 DEPOIS DAQUELE GOL   6443764.0
# 1400                                             KKKKKK   4975369.0
# 1401                                     MEIAS PALAVRAS  10821133.0
# 1402                                          SUPERÁVIT   6437246.0
# 1403                                        MODELO VIVO   4618664.0
# 1404                                            SPOLETO  16573691.0
# 1405                     BATMAN: THE DARK KNIGHT ERECTS   9635837.0
# 1406                                 CSI NOVA IGUAÇU #8   1183493.0
# 1407                    COCAÍNA - Porta Dos Fundos Nº 1   2324249.0
# 1408           TRAVECO DA FIRMA - Porta dos Fundos Nº 1  12185884.0
# 1409                               PORTA DOS FUNDOS N°1   8040264.0
#
#                                                    cast  \
# 1360                        Fábio Porchat,Luis Lobianco
# 1361  Mulher: Clarice Falcão,Homem: Rodrigo Magal,Do...
# 1362        Clarice Falcão,Fábio Porchat,Gabriel Totoro
# 1363                                      Julia Rabello
# 1364                       Julia Rabello,Rafael Infante
# 1365  Antonio Tabet,Clarice Falcão,Gregorio Duvivier...
# 1366  Fábio Porchat,Gabriel Totoro,Letícia Lima,Luis...
# 1367                       Clarice Falcão,Julia Rabello
# 1368                    Fábio Porchat,Gregorio Duvivier
# 1369                       Julia Rabello,Marcus Majella
# 1370  João Vicente de Castro,Fábio Porchat,Gabriel E...
# 1371        Luis Lobianco,Rafael Infante,Gustavo Chagas
# 1372                       Luis Lobianco,Rafael Infante
# 1373
# 1374                     Gregorio Duvivier,Letícia Lima
# 1375  Antonio Tabet,Douglas Silva,Gregorio Duvivier,...
# 1376         Clarice Falcão,Letícia Lima,Rafael Infante
# 1377  Julia Rabello,Fábio Porchat,Gabriel Totoro,Gre...
# 1378  Júlia Rabello,Letícia Lima,Gabriel Totoro,Giga...
# 1379             Antonio Tabet,Fábio Porchat,Cleo Pires
# 1380
# 1381  Fábio Porchat,Gregorio Duvivier,João Vicente d...
# 1382
# 1383     Antonio Tabet,Gregorio Duvivier,Gustavo Chagas
# 1384  Antonio Tabet,Gabriel Totoro,Fábio Porchat,Lui...
# 1385                       Clarice Falcão,Fábio Porchat
# 1386     Antonio Tabet,Clarice Falcão,Gregorio Duvivier
# 1387
# 1388          Letícia Lima,Luis Lobianco,Rafael Infante
# 1389
# 1390
# 1391
# 1392
# 1393
# 1394  Homem , Gregorio Duvivier,Outro homem , Camilo...
# 1395  Ator , Victor Leal,Jagunço , Gabriel Esteves,E...
# 1396  Homem , Alexandre Nero,Repórter , Clarice Falc...
# 1397                       Fábio Porchat,Marcus Majella
# 1398
# 1399                        Marcos Veras,Rafael Infante
# 1400     Fábio Porchat,Gregorio Duvivier,Gustavo Chagas
# 1401  Gregorio Duvivier,Letícia Lima,Luis Lobianco,R...
# 1402                         Fábio Porchat,Marcos Veras
# 1403  Antonio Tabet,Gregorio Duvivier,Gabriel Totoro...
# 1404            Clarice Falcão,Fábio Porchat,Camila Vaz
# 1405  Antonio Tabet,Fabio Porchat,Vitor Costa,Rafael...
# 1406  Antonio Tabet,Gabriel Totoro,Gustavo Chagas,Le...
# 1407                        Julia Rabello,Antonio Tabet
# 1408        Fabio Porchat,Gustavo Chagas,Rafael Infante
# 1409
#
#                                                  script directing  \
# 1360
# 1361
# 1362
# 1363
# 1364
# 1365
# 1366
# 1367
# 1368
# 1369
# 1370
# 1371
# 1372
# 1373
# 1374
# 1375
# 1376
# 1377                                                      Ian SBF
# 1378                                      Antonio Tabet   Ian SBF
# 1379                                                      Ian SBF
# 1380                                    Gabriel Esteves   Ian SBF
# 1381  Gabriel Esteves,Gabriel Totoro,Gustavo Chagas,...   Ian SBF
# 1382                                      Fabio Porchat   Ian SBF
# 1383                                      Antonio Tabet   Ian SBF
# 1384
# 1385
# 1386                                      Fabio Porchat   Ian SBF
# 1387
# 1388                                      Fabio Porchat   Ian SBF
# 1389
# 1390
# 1391
# 1392
# 1393
# 1394
# 1395
# 1396
# 1397                                      Fábio Porchat   Ian SBF
# 1398
# 1399                                  Gregorio Duvivier   Ian SBF
# 1400                                      Fábio Porchat   Ian SBF
# 1401                                  Gregorio Duvivier   Ian SBF
# 1402                                  Gregorio Duvivier   Ian SBF
# 1403                                      Antonio Tabet   Ian SBF
# 1404                                      Fábio Porchat   Ian SBF
# 1405  Antonio Tabet,Gabriel Totoro,Gabriel Esteves,G...   Ian SBF
# 1406                                      Antonio Tabet   Ian SBF
# 1407
# 1408
# 1409
#
#             date_published     likes  dislikes
# 1360  2012-12-20T12:59:20Z  103108.0    3088.0
# 1361  2012-12-17T16:50:53Z  275821.0    5362.0
# 1362  2012-12-13T12:58:03Z  233097.0    3116.0
# 1363  2012-12-10T12:57:41Z   53210.0    1629.0
# 1364  2012-12-06T12:58:26Z   92404.0    1736.0
# 1365  2012-12-03T13:00:28Z  157403.0    5723.0
# 1366  2012-11-29T12:59:57Z   33897.0    2476.0
# 1367  2012-11-26T12:58:44Z   33536.0    1105.0
# 1368  2012-11-22T13:01:39Z   99500.0    2128.0
# 1369  2012-11-19T12:57:48Z   63705.0    1352.0
# 1370  2012-11-18T23:05:03Z   29624.0     904.0
# 1371  2012-11-17T14:19:12Z   67260.0    1216.0
# 1372  2012-11-15T13:07:25Z   72126.0    1597.0
# 1373  2012-11-12T12:57:25Z   54890.0    1448.0
# 1374  2012-11-08T12:59:04Z  122314.0    5662.0
# 1375  2012-11-05T10:16:20Z  226044.0    4044.0
# 1376  2012-11-01T13:10:26Z  236542.0    7235.0
# 1377  2012-10-29T12:58:47Z   63630.0    3726.0
# 1378  2012-10-25T13:00:10Z  144107.0    2086.0
# 1379  2012-10-22T12:58:07Z   89154.0   14011.0
# 1380  2012-10-18T13:59:43Z   36061.0    3003.0
# 1381  2012-10-15T13:58:10Z  147408.0    6028.0
# 1382  2012-10-11T13:57:13Z  115100.0    2703.0
# 1383  2012-10-08T13:58:55Z  106331.0    9063.0
# 1384  2012-10-07T20:05:07Z   39273.0     801.0
# 1385  2012-10-06T23:47:17Z   25040.0    1199.0
# 1386  2012-10-04T13:58:59Z  134271.0    1516.0
# 1387  2012-10-01T13:58:52Z   39405.0     926.0
# 1388  2012-09-27T13:59:00Z  100064.0    3571.0
# 1389  2012-09-24T13:59:38Z  164599.0    5292.0
# 1390  2012-09-20T13:59:25Z  106158.0    2423.0
# 1391  2012-09-17T13:58:40Z  182763.0   15536.0
# 1392  2012-09-13T13:59:01Z   93921.0    2200.0
# 1393  2012-09-10T13:59:06Z  433957.0   14360.0
# 1394  2012-09-09T23:24:04Z   61163.0     954.0
# 1395  2012-09-08T23:31:47Z   40832.0     965.0
# 1396  2012-09-07T14:54:00Z   60135.0    1056.0
# 1397  2012-09-06T13:58:16Z  126516.0    2697.0
# 1398  2012-09-03T14:02:21Z   49209.0    1439.0
# 1399  2012-08-30T14:02:23Z       NaN       NaN
# 1400  2012-08-27T14:01:17Z  107376.0    2797.0
# 1401  2012-08-23T14:00:08Z  148562.0    5096.0
# 1402  2012-08-20T14:00:02Z       NaN       NaN
# 1403  2012-08-16T14:00:08Z       NaN       NaN
# 1404  2012-08-13T14:01:50Z       NaN       NaN
# 1405  2012-08-09T14:02:53Z  172363.0    4512.0
# 1406  2012-08-08T00:54:43Z       NaN       NaN
# 1407  2012-08-08T00:54:15Z       NaN       NaN
# 1408  2012-08-08T00:53:43Z       NaN       NaN
# 1409  2012-08-06T14:20:18Z       NaN       NaN

# %% [markdown]
# ### Dividindo atores, roteiristas e diretores em linhas

# %%
df_exploded = df.assign(cast=df.cast.str.split(",")).explode('cast')
df_exploded2 = df_exploded.assign(script=df_exploded.script.str.split(",")).explode('script')
df_exploded3 = df_exploded2.assign(directing=df_exploded2.directing.str.split(",")).explode('directing')
df_exploded3.shape
df_exploded3.tail(10)
# Out:
# (4369, 8)
#                                          title       views            cast  \
# 1406                        CSI NOVA IGUAÇU #8   1183493.0   Antonio Tabet
# 1406                        CSI NOVA IGUAÇU #8   1183493.0  Gabriel Totoro
# 1406                        CSI NOVA IGUAÇU #8   1183493.0  Gustavo Chagas
# 1406                        CSI NOVA IGUAÇU #8   1183493.0    Letícia Lima
# 1407           COCAÍNA - Porta Dos Fundos Nº 1   2324249.0   Julia Rabello
# 1407           COCAÍNA - Porta Dos Fundos Nº 1   2324249.0   Antonio Tabet
# 1408  TRAVECO DA FIRMA - Porta dos Fundos Nº 1  12185884.0   Fabio Porchat
# 1408  TRAVECO DA FIRMA - Porta dos Fundos Nº 1  12185884.0  Gustavo Chagas
# 1408  TRAVECO DA FIRMA - Porta dos Fundos Nº 1  12185884.0  Rafael Infante
# 1409                      PORTA DOS FUNDOS N°1   8040264.0
#
#              script directing        date_published  likes  dislikes
# 1406  Antonio Tabet   Ian SBF  2012-08-08T00:54:43Z    NaN       NaN
# 1406  Antonio Tabet   Ian SBF  2012-08-08T00:54:43Z    NaN       NaN
# 1406  Antonio Tabet   Ian SBF  2012-08-08T00:54:43Z    NaN       NaN
# 1406  Antonio Tabet   Ian SBF  2012-08-08T00:54:43Z    NaN       NaN
# 1407                           2012-08-08T00:54:15Z    NaN       NaN
# 1407                           2012-08-08T00:54:15Z    NaN       NaN
# 1408                           2012-08-08T00:53:43Z    NaN       NaN
# 1408                           2012-08-08T00:53:43Z    NaN       NaN
# 1408                           2012-08-08T00:53:43Z    NaN       NaN
# 1409                           2012-08-06T14:20:18Z    NaN       NaN

# %% [markdown]
# ### Convertendo o campo "date_published" de string para datetime

# %%
df_exploded3['dt_published'] = pd.to_datetime(df_exploded3['date_published'].str.slice(start=0, stop=10), format='%Y-%m-%d')
df_exploded3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4369 entries, 0 to 1409
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           4369 non-null   object
#  1   views           4369 non-null   float64
#  2   cast            4369 non-null   object
#  3   script          4369 non-null   object
#  4   directing       4369 non-null   object
#  5   date_published  4369 non-null   object
#  6   likes           4348 non-null   float64
#  7   dislikes        4348 non-null   float64
#  8   dt_published    4369 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 341.3+ KB

# %% [markdown]
# ### Convertendo todas as observações das variáveis string para minúsculo
# Isso é necessário para evitar que o python trate "Fábio de Luca" como sendo diferente de "Fábio de luca"

# %%
df_exploded4 = df_exploded3.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)
df_exploded4.head()
# Out:
#                          title     views            cast           script  \
# 0                  tá tudo bem  334867.0   fábio de luca  gabriel esteves
# 0                  tá tudo bem  334867.0  rafael infante  gabriel esteves
# 1                        katia  384456.0   evelyn castro      matheus mad
# 1                        katia  384456.0   fábio de luca      matheus mad
# 2  rir é um ato de resistência  412737.0
#
#           directing        date_published    likes  dislikes dt_published
# 0  zaga martelletto  2021-05-10t14:00:32z  44800.0     651.0   2021-05-10
# 0  zaga martelletto  2021-05-10t14:00:32z  44800.0     651.0   2021-05-10
# 1   bianca frossard  2021-05-08t14:00:11z  37581.0     511.0   2021-05-08
# 1   bianca frossard  2021-05-08t14:00:11z  37581.0     511.0   2021-05-08
# 2                    2021-05-06t14:00:04z  92594.0     688.0   2021-05-06

# %% [markdown]
# ### Dropando o campo "date_published" e salvando o dataframe em csv para utilização posterior

# %%
df_final = df_exploded4.drop(['date_published'], axis=1)
df_final.shape
df_final.head()
# Out:
# (4369, 8)
#                          title     views            cast           script  \
# 0                  tá tudo bem  334867.0   fábio de luca  gabriel esteves
# 0                  tá tudo bem  334867.0  rafael infante  gabriel esteves
# 1                        katia  384456.0   evelyn castro      matheus mad
# 1                        katia  384456.0   fábio de luca      matheus mad
# 2  rir é um ato de resistência  412737.0
#
#           directing    likes  dislikes dt_published
# 0  zaga martelletto  44800.0     651.0   2021-05-10
# 0  zaga martelletto  44800.0     651.0   2021-05-10
# 1   bianca frossard  37581.0     511.0   2021-05-08
# 1   bianca frossard  37581.0     511.0   2021-05-08
# 2                    92594.0     688.0   2021-05-06

# %%
df_final.to_csv('porta_dos_fundos_shortway_cleaned.csv', index=False)

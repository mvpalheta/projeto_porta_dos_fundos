# %% [markdown]
# # <center> Buscando dados de vídeos do YouTube - Parte 1 </center>
#
# <img src="youtube.com_.jpg" width="480">
#
# ### Objetivo
# Apresentar um exemplo de como baixar dados de vídeos de um canal do YouTube via webscraping utilizando Selenium e Beautifulsoup. Neste caso, foi utilizado o canal de humor "Porta dos Fundos"
#
# <b> Obs: Existem bibliotecas e a própria API do YouTube que simplificam bastante este processo, entretanto o objetivo deste tutorial é exemplificar como realizar esta tarefa utilizando exclusivamente webscraping. </b>
#
# Para importar nossa base de dados vamos utilizar a seguinte estratégia:<br>
# 1 - Abrir a página de vídeos do canal desejado e rolar até o final para retornar a lista de vídeos publicados no canal desejado;<br>
# 2 - em seguida, será realizado um loop através dos vídeos para obter informações como título, visualizações, elenco, diretor(a), roteiristas, likes, dislikes e data de publicação via webscraping, as quais serão armazenadas em um dicionário;<br>
# 3 - após isto, os dados serão carregados em um pandas dataframe e se procederá às devidas limpezas para se obter a base de dados final, pronta para análise.
# <br>
# <br>
# Vamos lá!!!

# %% [markdown]
# ### Importando as libraries necessárias

# %%
import requests
import re
from bs4 import BeautifulSoup as bs
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Abrindo a página de vídeos do canal "Porta dos Fundos" a fim de carregar os links de todos eles

# %%
# definindo esta função para rolar a página de vídeos até o final a fim de renderizar todos os links
def scroll_down(current_elements_count, driver, scroll_pause_time):
    driver.execute_script('window.scrollBy(0, 50000);')
    time.sleep(scroll_pause_time)
    new_elements_count = driver.execute_script('return document.querySelectorAll("ytd-grid-video-renderer").length')
    if new_elements_count == current_elements_count:
        time.sleep(scroll_pause_time * 2)
        new_elements_count = driver.execute_script('return document.querySelectorAll("ytd-grid-video-renderer").length')
        if new_elements_count == current_elements_count:
            print('Reached end of page!')
    return new_elements_count

channel = "https://www.youtube.com/c/PortadosFundos/videos"

driver = webdriver.Chrome()  
driver.get(channel)

scroll_pause_time = 3
current_elements_count = None
new_elements_count  = driver.execute_script('return document.querySelectorAll("ytd-grid-video-renderer").length')

while new_elements_count != current_elements_count:
    current_elements_count = new_elements_count
    new_elements_count  = scroll_down(current_elements_count, driver, scroll_pause_time)

soup = bs(driver.page_source, "html.parser")
driver.close()
# Out:
# Reached end of page!

# %% [markdown]
# ### Extraindo as tags com todos os ID's e títulos dos vídeos

# %%
find_all_a = soup.find_all('a',{ "class": "yt-simple-endpoint style-scope ytd-grid-video-renderer"})
len(find_all_a)
# Out:
# 1659

# %% [markdown]
# ### Extraindo títulos e ID's, formando os links e guardando tudo em um dicionário

# %%
videos = {"title":[], "url":[]}
for element in find_all_a:
    videos["title"].append(element.get_text())
    videos["url"].append("https://www.youtube.com"+element['href'])  
    
len(videos["title"])
# Out:
# 1659

# %% [markdown]
# ###  Carregando o dicionário em um dataframe e observando os primeiros registros

# %%
df = pd.DataFrame.from_dict(videos)
df.head()
# Out:
#                                           title  \
# 0                                EX-FUNCIONÁRIO
# 1                                      VACINADA
# 2        PLANTANANÃ - TUDO SOBRE A CPI DA COVID
# 3                                        PFIZER
# 4  PREOCUPADÃO COM A COVID #EuMeCuido - #Shorts
#
#                                            url
# 0  https://www.youtube.com/watch?v=5-D_GCwNHFk
# 1  https://www.youtube.com/watch?v=WxzlRVq_gpI
# 2  https://www.youtube.com/watch?v=E57UY6M8zo4
# 3  https://www.youtube.com/watch?v=PWwnNtl2Nyg
# 4  https://www.youtube.com/watch?v=0Prrv9jXgls

# %% [markdown]
# ### Excluindo os vídeos de making of para reduzir dupla contagem de atores/diretores/roteiristas na mesma peça

# %%
df_2 = df[~df['title'].str.contains('MAKING OF')]
df_2.shape
# Out:
# (1418, 2)

# %% [markdown]
# ### Gerando uma lista com as URL's dos vídeos

# %%
url_list = df_2["url"].tolist()
url_list[0:10]
len(url_list)
# Out:
# ['https://www.youtube.com/watch?v=5-D_GCwNHFk',
#  'https://www.youtube.com/watch?v=WxzlRVq_gpI',
#  'https://www.youtube.com/watch?v=E57UY6M8zo4',
#  'https://www.youtube.com/watch?v=PWwnNtl2Nyg',
#  'https://www.youtube.com/watch?v=0Prrv9jXgls',
#  'https://www.youtube.com/watch?v=mwzp_UZrNMo',
#  'https://www.youtube.com/watch?v=PfO5oPe___4',
#  'https://www.youtube.com/watch?v=ssB7KMSUuwk',
#  'https://www.youtube.com/watch?v=xsLrkt3XEaM',
#  'https://www.youtube.com/watch?v=onNxHMHBdoA']
# 1418

# %% [markdown]
# ### Realizando loop na lista de vídeos para baixar os dados desejados e guadá-los em um dicionário

# %%
# incializando o dicionário que irá guardar as informações extraídas dos vídeos
result = {"title":[], "views":[], "cast":[], "script":[], "directing":[], "date_published":[], "likes":[], "dislikes":[]}

n = 0

#Esta função verifica se a conexão com a internet está ativa
def has_connection2(url):
    timeout = 5
    try:
        request = requests.get(url, timeout=timeout)
        return True
    except (requests.ConnectionError, requests.Timeout) as exception:
        return False
    
for url in url_list:
    print(n)
    print(url)
    options = webdriver.ChromeOptions()
    options.add_argument('headless')
    # init webdriver
    driver = webdriver.Chrome(options=options)
    
    while has_connection2(url) == False:
        try:
            print("No internet connection.")            
            driver.close()
            time.sleep(2)
            driver = webdriver.Chrome()
        except:
             pass
            
    driver.get(url)
    time.sleep(4)

    # create beautiful soup object to parse HTML            
    soup = bs(driver.page_source, "html.parser")    
    description = str(driver.execute_script('return ytInitialPlayerResponse').get('microformat').get('playerMicroformatRenderer').get('description'))
    driver.close()
    
    # Padronizando alguns termos
    for character in ['Elenco', 'Elenco:', 'elenco', 'ELENCO:', "ELENCO "]:
        description = description.replace(character, "ELENCO")

    for character in ['Roteiro', 'Roteiro:', 'roteiro', 'ROTEIRO:', "ROTEIRO "]:
        description = description.replace(character, "ROTEIRO")

    for character in ['Direção', 'Direção:', 'direção', 'DIREÇÃO:', "DIREÇÃO "]:
        description = description.replace(character, "DIREÇÃO")

    for character in [' \\n ', ' \\n', '\\n ']:
        description = description.replace(character, "\\n")

    #title
    result["title"].append(soup.find("h1").text.strip())
    #views
    result["views"].append(soup.find("span", attrs={"class": "view-count"}).text)
    #cast
    result["cast"].append(''.join(re.findall(r'\\nELENCO\\n(.*?)\\n\\n', description)))
    #script
    result["script"].append(''.join(re.findall(r'\\nROTEIRO\\n(.*?)\\n\\n', description)))
    #directing
    result["directing"].append(''.join(re.findall(r'\\nDIREÇÃO\\n(.*?)\\n\\n', description)))
    # date published
    result["date_published"].append(soup.find("meta", {"itemprop":"datePublished"})['content'])
    #likes
    elem_likes_dislikes = soup.find_all("yt-formatted-string", {"id": "text", "class": "ytd-toggle-button-renderer"})
    str_like = ''.join(re.findall(r'yt-formatted-string(.*?)class="style-scope',str(elem_likes_dislikes[0]).replace(".","")))
    result["likes"].append(''.join(re.findall('\d+', str_like)))
    #dislikes
    str_dislike = ''.join(re.findall(r'yt-formatted-string(.*?)class="style-scope',str(elem_likes_dislikes[1]).replace(".","")))
    result["dislikes"].append(''.join(re.findall('\d+', str_dislike)))
    n = n + 1
# Out:
# 0
# https://www.youtube.com/watch?v=U317keQNZfA
# 1
# https://www.youtube.com/watch?v=dh6e7qStJqk
# 2
# https://www.youtube.com/watch?v=S0F8Ggt-MbU
# 3
# https://www.youtube.com/watch?v=GVTQO9czBsI
# 4
# https://www.youtube.com/watch?v=oZWC3Gi7EzA
# 5
# https://www.youtube.com/watch?v=FJYNH7V3FJ4
# 6
# https://www.youtube.com/watch?v=Kif3YLMtP3I
# 7
# https://www.youtube.com/watch?v=rc99KJh9nd8
# 8
# https://www.youtube.com/watch?v=Zyn9MY4tFjs
# 9
# https://www.youtube.com/watch?v=57LC5gY2kno
# 10
# https://www.youtube.com/watch?v=ketFMlwR_wM
# 11
# https://www.youtube.com/watch?v=Bnac_rH3lIA
# 12
# https://www.youtube.com/watch?v=NKmXNe-hdug
# 13
# https://www.youtube.com/watch?v=7kQ_KkkzMXo
# 14
# https://www.youtube.com/watch?v=7eFF6avQNG0
# 15
# https://www.youtube.com/watch?v=31Bi_1yrZqw
# 16
# https://www.youtube.com/watch?v=hI_M_Dw5Qak
# 17
# https://www.youtube.com/watch?v=7ypLzROMo-E
# 18
# https://www.youtube.com/watch?v=w7r8pjnXYrM
# 19
# https://www.youtube.com/watch?v=WtLdVKMhcj8
# 20
# https://www.youtube.com/watch?v=T5MohmJ9bB4
# 21
# https://www.youtube.com/watch?v=bEf2JXHwW5c
# 22
# https://www.youtube.com/watch?v=FsQ-9IhgUMI
# 23
# https://www.youtube.com/watch?v=dssida3eLsw
# 24
# https://www.youtube.com/watch?v=dTIg6v_IWnI
# 25
# https://www.youtube.com/watch?v=uxVmIlReIMI
# 26
# https://www.youtube.com/watch?v=P0QCqyrNUig
# 27
# https://www.youtube.com/watch?v=8f3qNxuum18
# 28
# https://www.youtube.com/watch?v=OaaUrHnOKKY
# 29
# https://www.youtube.com/watch?v=VafPPmlNlbQ
# 30
# https://www.youtube.com/watch?v=WwjFef28juw
# 31
# https://www.youtube.com/watch?v=b-dEnGXEtpM
# 32
# https://www.youtube.com/watch?v=XjDEXeQ0XDs
# 33
# https://www.youtube.com/watch?v=4hEf-h3EHiY
# 34
# https://www.youtube.com/watch?v=BLqxR1YXZj4
# 35
# https://www.youtube.com/watch?v=Pl_PS5laYm8
# 376
# https://www.youtube.com/watch?v=LVYM6u_v52k
# 377
# https://www.youtube.com/watch?v=MX0_ZvcVBco
# 378
# https://www.youtube.com/watch?v=B0M_pRh2hNw
# 379
# https://www.youtube.com/watch?v=03riiu2ENC0
# 380
# https://www.youtube.com/watch?v=78SYW5JJu24
# 381
# https://www.youtube.com/watch?v=FY0xGSugf44
# 382
# https://www.youtube.com/watch?v=il-cG20QeG4
# 383
# https://www.youtube.com/watch?v=BxlfjHl9XUE
# 384
# https://www.youtube.com/watch?v=QDwQEWWYOz8
# 385
# https://www.youtube.com/watch?v=GY9Aiieerrk
# 386
# https://www.youtube.com/watch?v=6EYmKAs7mzc
# 387
# https://www.youtube.com/watch?v=r4XLZwqplzU
# 388
# https://www.youtube.com/watch?v=1-g6C-2M4dI
# 389
# https://www.youtube.com/watch?v=JJay_JGQDvQ
# 390
# https://www.youtube.com/watch?v=qTqe8Ecco5I
# 391
# https://www.youtube.com/watch?v=_YNbmchh5Xk
# 392
# https://www.youtube.com/watch?v=j3MeZ-MIzME
# 393
# https://www.youtube.com/watch?v=nmQDRAEQSnc
# 394
# https://www.youtube.com/watch?v=NH_3Iw8pL6A
# 395
# https://www.youtube.com/watch?v=WFd5_YtbScs
# 396
# https://www.youtube.com/watch?v=gEbR-UaE-vw
# 397
# https://www.youtube.com/watch?v=Un4r52t-cuk
# 398
# https://www.youtube.com/watch?v=ksC-acvvw-4
# 399
# https://www.youtube.com/watch?v=5Mc18dkiTYQ
# 400
# https://www.youtube.com/watch?v=8qxjuTV9guU
# 401
# https://www.youtube.com/watch?v=Tv5b4JBGp-k
# 402
# https://www.youtube.com/watch?v=eQmDdD5f-Ic

# %% [markdown]
# ### Carregando os dados em um dataframe para realizar as limpezas necessárias

# %%
#df = pd.read_csv('porta_dos_fundos_long_raw.csv')
df = pd.DataFrame.from_dict(result)
df.shape
df.tail()
# Out:
# (1418, 8)
#                                          title                     views  \
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1414                        CSI NOVA IGUAÇU #8   1.183.997 visualizações
# 1415           COCAÍNA - Porta Dos Fundos Nº 1   2.325.550 visualizações
# 1416  TRAVECO DA FIRMA - Porta dos Fundos Nº 1  12.198.167 visualizações
# 1417                      PORTA DOS FUNDOS N°1   8.045.907 visualizações
#
#                                                    cast  \
# 1413  Antonio Tabet\nFabio Porchat\nVitor Costa\nRaf...
# 1414  Antonio Tabet\nGabriel Totoro\nGustavo Chagas\...
# 1415                       Julia Rabello\nAntonio Tabet
# 1416      Fabio Porchat\nGustavo Chagas\nRafael Infante
# 1417                                                NaN
#
#                                                  script directing  \
# 1413  Antonio Tabet\nGabriel Totoro\nGabriel Esteves...   Ian SBF
# 1414                                      Antonio Tabet   Ian SBF
# 1415                                                NaN       NaN
# 1416                                                NaN       NaN
# 1417                                                NaN       NaN
#
#      date_published     likes  dislikes
# 1413     2012-08-09  172821.0    4519.0
# 1414     2012-08-07       NaN       NaN
# 1415     2012-08-07       NaN       NaN
# 1416     2012-08-07       NaN       NaN
# 1417     2012-08-06       NaN       NaN

# %% [markdown]
# ### Extraindo a quantidade de visualizações da variável "views" e convertendo em numérico

# %%
df['views_num'] = df.views.str.extract(r'(\d+[.\d]*)')
df['views_num'] = df.views_num.str.replace('.', '').astype(int)
# Out:
# <ipython-input-22-8ce3324039c1>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['views_num'] = df.views_num.str.replace('.', '').astype(int)

# %%
df.head()
df.info()
# Out:
#                                           title                  views  \
# 0                                EX-FUNCIONÁRIO  404.536 visualizações
# 1                                      VACINADA  527.924 visualizações
# 2        PLANTANANÃ - TUDO SOBRE A CPI DA COVID  322.293 visualizações
# 3                                        PFIZER  888.119 visualizações
# 4  PREOCUPADÃO COM A COVID #EuMeCuido - #Shorts  126.044 visualizações
#
#                                                 cast                  script  \
# 0     Evelyn Castro\nEstevam Nabote\nNoemia Oliveira           Pedro Esteves
# 1                                        Thati Lopes       Gregório Duvivier
# 2                                     Rafael Infante  João Vicente de Castro
# 3  Antonio Tabet\nFábio Porchat\nJoão Vicente de ...       Gregório Duvivier
# 4                                        Joel Vieira        Jhonatan Marques
#
#              directing date_published     likes  dislikes  views_num
# 0     Zaga Martelletto     2021-05-24   46470.0     379.0     404536
# 1      Bianca Frossard     2021-05-22   64951.0    1596.0     527924
# 2          Vini Videla     2021-05-21   44357.0    1522.0     322293
# 3  Rodrigo Van Der Put     2021-05-20  126596.0    3800.0     888119
# 4                  NaN     2021-05-19    7483.0     646.0     126044
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1418 entries, 0 to 1417
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           1418 non-null   object
#  1   views           1418 non-null   object
#  2   cast            1229 non-null   object
#  3   script          136 non-null    object
#  4   directing       92 non-null     object
#  5   date_published  1418 non-null   object
#  6   likes           1410 non-null   float64
#  7   dislikes        1410 non-null   float64
#  8   views_num       1418 non-null   int32
# dtypes: float64(2), int32(1), object(6)
# memory usage: 94.3+ KB

# %% [markdown]
# ### Substituindo o '\\\n' por vírgula para facilitar dividir atores, roteiristas e diretores em linhas

# %%
df['cast'] = df['cast'].replace(r'\\n',',', regex=True)
df['script'] = df['script'].replace(r'\\n',',', regex=True)
df['directing'] = df['directing'].replace(r'\\n',',', regex=True)

# %%
df.head()
# Out:
#                                           title                  views  \
# 0                                EX-FUNCIONÁRIO  404.536 visualizações
# 1                                      VACINADA  527.924 visualizações
# 2        PLANTANANÃ - TUDO SOBRE A CPI DA COVID  322.293 visualizações
# 3                                        PFIZER  888.119 visualizações
# 4  PREOCUPADÃO COM A COVID #EuMeCuido - #Shorts  126.044 visualizações
#
#                                                 cast                  script  \
# 0       Evelyn Castro,Estevam Nabote,Noemia Oliveira           Pedro Esteves
# 1                                        Thati Lopes       Gregório Duvivier
# 2                                     Rafael Infante  João Vicente de Castro
# 3  Antonio Tabet,Fábio Porchat,João Vicente de Ca...       Gregório Duvivier
# 4                                        Joel Vieira        Jhonatan Marques
#
#              directing date_published     likes  dislikes  views_num
# 0     Zaga Martelletto     2021-05-24   46470.0     379.0     404536
# 1      Bianca Frossard     2021-05-22   64951.0    1596.0     527924
# 2          Vini Videla     2021-05-21   44357.0    1522.0     322293
# 3  Rodrigo Van Der Put     2021-05-20  126596.0    3800.0     888119
# 4                  NaN     2021-05-19    7483.0     646.0     126044

# %% [markdown]
# ### Dividindo atores, roteiristas e diretores em linhas

# %%
df_exploded = df.assign(cast=df.cast.str.split(",")).explode('cast')
df_exploded2 = df_exploded.assign(script=df_exploded.script.str.split(",")).explode('script')
df_exploded3 = df_exploded2.assign(directing=df_exploded2.directing.str.split(",")).explode('directing')
df_exploded3.shape
df_exploded3.tail(10)
# Out:
# (4366, 9)
#                                          title                     views  \
# 1414                        CSI NOVA IGUAÇU #8   1.183.997 visualizações
# 1414                        CSI NOVA IGUAÇU #8   1.183.997 visualizações
# 1414                        CSI NOVA IGUAÇU #8   1.183.997 visualizações
# 1414                        CSI NOVA IGUAÇU #8   1.183.997 visualizações
# 1415           COCAÍNA - Porta Dos Fundos Nº 1   2.325.550 visualizações
# 1415           COCAÍNA - Porta Dos Fundos Nº 1   2.325.550 visualizações
# 1416  TRAVECO DA FIRMA - Porta dos Fundos Nº 1  12.198.167 visualizações
# 1416  TRAVECO DA FIRMA - Porta dos Fundos Nº 1  12.198.167 visualizações
# 1416  TRAVECO DA FIRMA - Porta dos Fundos Nº 1  12.198.167 visualizações
# 1417                      PORTA DOS FUNDOS N°1   8.045.907 visualizações
#
#                 cast         script directing date_published  likes  dislikes  \
# 1414   Antonio Tabet  Antonio Tabet   Ian SBF     2012-08-07    NaN       NaN
# 1414  Gabriel Totoro  Antonio Tabet   Ian SBF     2012-08-07    NaN       NaN
# 1414  Gustavo Chagas  Antonio Tabet   Ian SBF     2012-08-07    NaN       NaN
# 1414    Letícia Lima  Antonio Tabet   Ian SBF     2012-08-07    NaN       NaN
# 1415   Julia Rabello            NaN       NaN     2012-08-07    NaN       NaN
# 1415   Antonio Tabet            NaN       NaN     2012-08-07    NaN       NaN
# 1416   Fabio Porchat            NaN       NaN     2012-08-07    NaN       NaN
# 1416  Gustavo Chagas            NaN       NaN     2012-08-07    NaN       NaN
# 1416  Rafael Infante            NaN       NaN     2012-08-07    NaN       NaN
# 1417             NaN            NaN       NaN     2012-08-06    NaN       NaN
#
#       views_num
# 1414    1183997
# 1414    1183997
# 1414    1183997
# 1414    1183997
# 1415    2325550
# 1415    2325550
# 1416   12198167
# 1416   12198167
# 1416   12198167
# 1417    8045907

# %%
df_exploded4 = df_exploded3.assign(cast=df_exploded3.cast.str.split("-")).explode('cast')
df_exploded4.shape
df_exploded4.tail(50)
# Out:
# (4389, 9)
#                                          title                     views  \
# 1408                                    KKKKKK   4.993.544 visualizações
# 1408                                    KKKKKK   4.993.544 visualizações
# 1409                            MEIAS PALAVRAS  10.831.846 visualizações
# 1409                            MEIAS PALAVRAS  10.831.846 visualizações
# 1409                            MEIAS PALAVRAS  10.831.846 visualizações
# 1409                            MEIAS PALAVRAS  10.831.846 visualizações
# 1410                                 SUPERÁVIT   6.447.232 visualizações
# 1410                                 SUPERÁVIT   6.447.232 visualizações
# 1411                               MODELO VIVO   4.619.487 visualizações
# 1411                               MODELO VIVO   4.619.487 visualizações
# 1411                               MODELO VIVO   4.619.487 visualizações
# 1411                               MODELO VIVO   4.619.487 visualizações
# 1412                                   SPOLETO  16.586.251 visualizações
# 1412                                   SPOLETO  16.586.251 visualizações
# 1412                                   SPOLETO  16.586.251 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 1413            BATMAN: THE DARK KNIGHT ERECTS   9.650.450 visualizações
# 
# 1413      Fabio Porchat     Gustavo Chagas   Ian SBF     2012-08-09  172821.0
# 1413      Fabio Porchat            Ian SBF   Ian SBF     2012-08-09  172821.0
# 1413        Vitor Costa      Antonio Tabet   Ian SBF     2012-08-09  172821.0
# 1413        Vitor Costa     Gabriel Totoro   Ian SBF     2012-08-09  172821.0
# 1413        Vitor Costa    Gabriel Esteves   Ian SBF     2012-08-09  172821.0
# 1413        Vitor Costa     Gustavo Chagas   Ian SBF     2012-08-09  172821.0
# 1413        Vitor Costa            Ian SBF   Ian SBF     2012-08-09  172821.0
# 1413     Rafael Infante      Antonio Tabet   Ian SBF     2012-08-09  172821.0
# 1413     Rafael Infante     Gabriel Totoro   Ian SBF     2012-08-09  172821.0
# 1413     Rafael Infante    Gabriel Esteves   Ian SBF     2012-08-09  172821.0
# 1413     Rafael Infante     Gustavo Chagas   Ian SBF     2012-08-09  172821.0
# 1413     Rafael Infante            Ian SBF   Ian SBF     2012-08-09  172821.0
# 1413        Thati Lopes      Antonio Tabet   Ian SBF     2012-08-09  172821.0
# 1413        Thati Lopes     Gabriel Totoro   Ian SBF     2012-08-09  172821.0
# 1413        Thati Lopes    Gabriel Esteves   Ian SBF     2012-08-09  172821.0
# 1413        Thati Lopes     Gustavo Chagas   Ian SBF     2012-08-09  172821.0
# 1413        Thati Lopes            Ian SBF   Ian SBF     2012-08-09  172821.0
# 1414      Antonio Tabet      Antonio Tabet   Ian SBF     2012-08-07       NaN
# 1414     Gabriel Totoro      Antonio Tabet   Ian SBF     2012-08-07       NaN
# 1414     Gustavo Chagas      Antonio Tabet   Ian SBF     2012-08-07       NaN
# 1414       Letícia Lima      Antonio Tabet   Ian SBF     2012-08-07       NaN
# 1415      Julia Rabello                NaN       NaN     2012-08-07       NaN
# 1415      Antonio Tabet                NaN       NaN     2012-08-07       NaN
# 1416      Fabio Porchat                NaN       NaN     2012-08-07       NaN
# 1416     Gustavo Chagas                NaN       NaN     2012-08-07       NaN
# 1416     Rafael Infante                NaN       NaN     2012-08-07       NaN
# 1417                NaN                NaN       NaN     2012-08-06       NaN
#
#       dislikes  views_num
# 1408    2831.0    4993544
# 1408    2831.0    4993544
# 1409    5104.0   10831846
# 1409    5104.0   10831846
# 1409    5104.0   10831846
# 1409    5104.0   10831846
# 1410       NaN    6447232
# 1410       NaN    6447232
# 1411       NaN    4619487
# 1411       NaN    4619487
# 1411       NaN    4619487
# 1411       NaN    4619487
# 1412       NaN   16586251
# 1412       NaN   16586251
# 1412       NaN   16586251
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1413    4519.0    9650450
# 1414       NaN    1183997
# 1414       NaN    1183997
# 1414       NaN    1183997
# 1414       NaN    1183997
# 1415       NaN    2325550
# 1415       NaN    2325550
# 1416       NaN   12198167
# 1416       NaN   12198167
# 1416       NaN   12198167
# 1417       NaN    8045907

# %% [markdown]
# ### Convertendo o campo "date_published" de string para datetime

# %%
df_exploded4['date_published'] = pd.to_datetime(df_exploded4['date_published'].str.slice(start=0, stop=10), format='%Y-%m-%d')
df_exploded4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4389 entries, 0 to 1417
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           4389 non-null   object
#  1   views           4389 non-null   object
#  2   cast            4167 non-null   object
#  3   script          542 non-null    object
#  4   directing       330 non-null    object
#  5   date_published  4389 non-null   datetime64[ns]
#  6   likes           4368 non-null   float64
#  7   dislikes        4368 non-null   float64
#  8   views_num       4389 non-null   int32
# dtypes: datetime64[ns](1), float64(2), int32(1), object(5)
# memory usage: 325.7+ KB

# %% [markdown]
# ### Convertendo todas as observações das variáveis string para minúsculo
# Isso é necessário para evitar que o python trate "Fábio de Luca" como sendo diferente de "Fábio de luca"

# %%
df_exploded5 = df_exploded4.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)
df_exploded5.head()
# Out:
#                                     title                  views  \
# 0                          ex-funcionário  404.536 visualizações
# 0                          ex-funcionário  404.536 visualizações
# 0                          ex-funcionário  404.536 visualizações
# 1                                vacinada  527.924 visualizações
# 2  plantananã - tudo sobre a cpi da covid  322.293 visualizações
#
#               cast                  script         directing date_published  \
# 0    evelyn castro           pedro esteves  zaga martelletto     2021-05-24
# 0   estevam nabote           pedro esteves  zaga martelletto     2021-05-24
# 0  noemia oliveira           pedro esteves  zaga martelletto     2021-05-24
# 1      thati lopes       gregório duvivier   bianca frossard     2021-05-22
# 2   rafael infante  joão vicente de castro       vini videla     2021-05-21
#
#      likes  dislikes  views_num
# 0  46470.0     379.0     404536
# 0  46470.0     379.0     404536
# 0  46470.0     379.0     404536
# 1  64951.0    1596.0     527924
# 2  44357.0    1522.0     322293

# %% [markdown]
# ### Dropando o campo "views"

# %%
df_final = df_exploded5.drop(['views'], axis=1)

# %%
df_final.shape
df_final.head()
# Out:
# (4389, 8)
#                                     title             cast  \
# 0                          ex-funcionário    evelyn castro
# 0                          ex-funcionário   estevam nabote
# 0                          ex-funcionário  noemia oliveira
# 1                                vacinada      thati lopes
# 2  plantananã - tudo sobre a cpi da covid   rafael infante
#
#                    script         directing date_published    likes  dislikes  \
# 0           pedro esteves  zaga martelletto     2021-05-24  46470.0     379.0
# 0           pedro esteves  zaga martelletto     2021-05-24  46470.0     379.0
# 0           pedro esteves  zaga martelletto     2021-05-24  46470.0     379.0
# 1       gregório duvivier   bianca frossard     2021-05-22  64951.0    1596.0
# 2  joão vicente de castro       vini videla     2021-05-21  44357.0    1522.0
#
#    views_num
# 0     404536
# 0     404536
# 0     404536
# 1     527924
# 2     322293

# %% [markdown]
# ### Pronto !!!
# O Dataframe acima está pronto para ser analisado. Acrescentei as duas linhas abaixo, caso seja necessário salvar e ler o arquivo em csv.

# %%
df_final.to_csv('porta_dos_fundos_longway_cleaned.csv', index=False)

# %%
df_analise = pd.read_csv('porta_dos_fundos_longway_cleaned.csv', parse_dates=['date_published'])

# %% [markdown]
# ### Conclusão
# Este exemplo apresentou uma forma de baixar dados de videos do YouTube sem a necessidade de cadastro no mesmo ou de gerar chave de API. Embora possa ser útil, não é forma mais recomendada pois o código fonte das páginas do YouTube ser alterado a qualquer momento e este método precisará ser reajustado.<br>
# Assim, para um uso mais confiável, sugiro que você use a API do YouTube para extrair os dados. Esta forma de extração será apresentada na parte 2 deste tutorial.
